# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as imageio

# %%
# %matplotlib inline

# %%
img = imageio.imread('stinkbug.png')
img = img.astype('float32')
img
# Out:
# array([[[104., 104., 104.],
#         [104., 104., 104.],
#         [104., 104., 104.],
#         ...,
#         [109., 109., 109.],
#         [109., 109., 109.],
#         [109., 109., 109.]],
#
#        [[105., 105., 105.],
#         [105., 105., 105.],
#         [105., 105., 105.],
#         ...,
#         [109., 109., 109.],
#         [109., 109., 109.],
#         [109., 109., 109.]],
#
#        [[107., 107., 107.],
#         [106., 106., 106.],
#         [106., 106., 106.],
#         ...,
#         [110., 110., 110.],
#         [110., 110., 110.],
#         [110., 110., 110.]],
#
#        ...,
#
#        [[112., 112., 112.],
#         [111., 111., 111.],
#         [110., 110., 110.],
#         ...,
#         [116., 116., 116.],
#         [115., 115., 115.],
#         [115., 115., 115.]],
#
#        [[113., 113., 113.],
#         [113., 113., 113.],
#         [112., 112., 112.],
#         ...,
#         [115., 115., 115.],
#         [114., 114., 114.],
# ...

# %%
plt.imshow(img/img.max())

# %%
ausschnitt = img[150:250,200:300,:]
plt.imshow(ausschnitt/ausschnitt.max())

# %%
blau = img[:,:,2]
plt.imshow(blau)

# %%
plt.imshow(blau, cmap='nipy_spectral')
plt.colorbar()

# %%
imageio.imwrite('ausschnitt.png', ausschnitt.astype('uint8'))
a=imageio.imread('ausschnitt.png')
a.max()
# Out:
# 216
